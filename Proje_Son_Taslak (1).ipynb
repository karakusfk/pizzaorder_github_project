# %%
import datetime

pizza_menu = {1:"Klasik Pizza", 2:"Sade Pizza", 3:"Margarita", 4:"Türk Pizza"}
extra_menu = {11: "Zeytin", 12: "Mantarlar", 13: "Keçi Peyniri", 14: "Et", 15: "Soğan", 16: "Mısır"} #en son yaptığım düzenleme ile bu dictionary boşa çıkmış oldu 

class Pizza: #ilk olarak pizza sınıfımı belirledim
    def __init__(self, p_style, p_cost, p_info):
        self.p_style = p_style  #pizza adı (tabanı)
        self.p_cost = p_cost  #pizza fiyatı
        self.p_info = p_info  #pizza açıklaması (değişken içerisinde info olarak kullandım ancak methodu olarak description olarak adlandırdım. decription, ürün fiyatını da içeren bir geniş bilgi fişi oldu)
     
    def get_pizza_description(self):
        print(f"{self.p_style}, {self.p_cost}TL.\n{self.p_info}")

turk_pizza = Pizza("Türk Pizza", 115, "Geleneksel Türk Mutfağı Lezzetleri ile Harmanlanmış Pizza!\n") #pizza sınıfıma pizza türleri olan instance'larımı girdim
#turk_pizza.get_pizza_description()
sade_pizza = Pizza("Sade Pizza", 85, "Lezzeti Yoğun Kendisi Sade!\n")
#sade_pizza.get_pizza_description()
margarita_pizza = Pizza("Margarita", 95, "Enfes Mozeralla Peyniri ve Taze Fesleğen ile...\n")
#margarita_pizza.get_pizza_description()
klasik_pizza = Pizza("Klasik Pizza", 75, "Klasik Olsun Bizim Olsun Diyenlere...\n")
#klasik_pizza.get_pizza_description()

class Extras:
    def __init__(self, x_style, x_cost, x_info): #aynı işlemi soslar olacak olan extras sınıfı için de yaptım
        self.x_style = x_style  #ek ürün adı
        self.x_cost = x_cost  #ek ürün fiyatı
        self.x_info = x_info #ek ürün açıklaması
    
    def get_extras_description(self):
        print(f"Ek ürün: {self.x_style}. Fiyatı: {self.x_cost}TL\n{self.x_info}\n")

x_zeytin = Extras("Ekstra Zeytin", 15, "İnce Doğranmış Siyah Zeytin.")
#x_zeytin.get_extras_description()
x_mantar = Extras("Kültür Mantarı", 10, "İnce Kesim Kültür Mantarı.")
#x_mantar.get_extras_description()
x_keci_peyniri = Extras("Keçi Peyniri", 25, "Taze Keçi Peyniri.")
#x_keci_peyniri.get_extras_description()
x_et = Extras("Kırmızı Et", 35, "Kavrulmuş, Jülyen Kırmızı Et.")
#x_et.get_extras_description()
x_sogan = Extras("Soğan", 15, "İnce Kesim Beyaz Soğan")
#x_sogan.get_extras_description()
x_misir = Extras("Mısır", 15, "Tane Süt Mısır.")
#x_misir.get_extras_description()

def show_menu():
  print("*****PİZZALAR*****")
  turk_pizza.get_pizza_description() #program açılışında bizi bir menü karşılayacak.
  sade_pizza.get_pizza_description()
  margarita_pizza.get_pizza_description()
  klasik_pizza.get_pizza_description()
  print("******EK MALZEMELER******")
  x_zeytin.get_extras_description()
  x_mantar.get_extras_description()
  x_keci_peyniri.get_extras_description()
  x_et.get_extras_description()
  x_sogan.get_extras_description()
  x_misir.get_extras_description()
  
def display_header():
  print("Merhaba Hoşgeldiniz. Siparişinizi Almaya Hazırım!\n") #giriş ve çıkış olarak, header ve outer tasarladım

def display_goodbye():
  print("\nBizi Seçtiğiniz İçin Teşkkürler! Siparişinizi Hazırlıyoruz.\n\nAfiyet Olsun!")

def add_pizza():
  print("Pizzanızı Seçiniz")
  pizza_choice = str(input("(1)Klasik Pizza, (2)Sade Pizza, (3)Margarita, (4)Türk Pizza, Onay İçin (ENTER) \n---> Seçiminiz: \n"))[0]    #bu fonksiyon bizim pizza seçim fonksiyonumuz
  return pizza_choice

def add_extra():
  print("Ekstra Ürün Seçiniz")
  extra_choice = input("(11)Zeytin, (12)Mantarlar, (13)Keçi Peyniri, (14)Et, (15)Soğan, (16)Mısır \n---> Seçiminiz: \n")[:2] #bu da sos seçim fonksiyonu
  return extra_choice

def get_customer_info(): #ürün seçimi tamamlandıktan sonra müşteri bilgilerini talep eden bir input fonksiyonu tasarladım
  print("Lütfen Kişi Bilgilerinizi Giriniz.")
  firstname = input("İsim: ").capitalize()
  last_name = input("Soyisim: ").capitalize()
  email = input("E-mail: ")
  print(f"BİLGİLERİNİZ\nİsim: {firstname} {last_name} - Email: {email}\n")
  print("Adres Bilgilerinizi Giriniz")
  street = input("Sokak: ")
  city = input("Şehir: ").upper()
  door_number = input("Kapı Numaranız: ")
  print(f"\nADRESİNİZ\n{street}, {door_number} no, {city}.\n")
  print("Ödeme Bilgilerinizi Giriniz")
  card_no = input("Kart Numaranız (16 Hane): ")
  exp_date = input("Son Kullanma Tarihi (AA/YY): ")
  cvc = input("CVC No: ")
  print(f"Kart Bilgileriniz: {card_no}. Tutar: {total}\n")
  print(f"\n*****SİPARİŞ BİLGİLERİNİZ*****\nİsim - Soyisim: {firstname} {last_name}\nEmail: {email}\nAdres Bilgileriniz: {street}, {door_number}, {city}\nKart Bilginiz: {card_no}\nSepet:{sepet}\nÜcret: {total}TL")
  order_time = datetime.datetime.now()
  print(order_time)
  #file_name = input("Siparişinizi Kaydetmek İçin Bir Dosya Adı Giriniz: ") #son olarak ise siparişin kaydedilmesi adına yazdırma fonksiyonu ekledim.
  f = open("order_list.txt","w")
  f.write(f"*****SİPARİŞ BİLGİLERİNİZ*****\nİsim - Soyisim: {firstname} {last_name}\nEmail: {email}\nAdres Bilgileriniz: {street}, {door_number}, {city}\nKart Bilginiz: {card_no}\nSepet: {sepet}\nÜcret: {total}TL\nSipariş Tarihi: {order_time}")
  f.close()

if __name__ == "__main__":
  
  display_header()
  
  show_menu()
  sepet = []
  total = 0
  
  pizza_choice = add_pizza()
  if pizza_choice == "1":
    print("Klasik Pizza Sepetinize Eklendi.\n")
    total += klasik_pizza.p_cost
    sepet.append(klasik_pizza.p_style)
    print(f"Sepetiniz: {sepet}, Güncel Tutar: {total}TL")  
  elif pizza_choice == "2":
    print("Sade Pizza Sepetinize Eklendi.\n")
    total += sade_pizza.p_cost
    sepet.append(sade_pizza.p_style)
    print(f"Sepetiniz: {sepet}, Güncel Tutar: {total}TL")
  elif pizza_choice == "3":
    print("Margarita Sepetinize Eklendi.\n")
    total += margarita_pizza.p_cost
    sepet.append(margarita_pizza.p_style)
    print(f"Sepetiniz: {sepet}, Güncel Tutar: {total}TL")
  elif pizza_choice == "4":
    print("Türk Pizza Sepetinize Eklendi.\n")
    total += turk_pizza.p_cost
    sepet.append(turk_pizza.p_style)
    print(f"Sepetiniz: {sepet}, Güncel Tutar: {total}TL")
     
  extra_choice = add_extra()
  if extra_choice == "11":
    print("Zeytin Sepetinize Eklendi.\n")
    total += x_zeytin.x_cost
    sepet.append("Zeytin")
    print(f"Sepetiniz: {sepet}, Güncel Tutar: {total}TL")
  elif extra_choice == "12":
    print("Mantar Sepetinize Eklendi.\n")
    total += x_mantar.x_cost
    sepet.append("Mantar")
    print(f"Sepetiniz: {sepet}, Güncel Tutar: {total}TL")
  elif extra_choice == "13":
    print("Keçi Peyniri Sepetinize Eklendi.\n")
    total += x_keci_peyniri.x_cost
    sepet.append("Keçi Peyniri")
    print(f"Sepetiniz: {sepet}, Güncel Tutar: {total}TL")
  elif extra_choice == "14":
    print("Et Sepetinize Eklendi.\n")
    total += x_et.x_cost
    sepet.append("Et")
    print(f"Sepetiniz: {sepet}, Güncel Tutar: {total}TL")
  elif extra_choice == "15":
    print("Soğan Sepetinize Eklendi.\n")
    total += x_sogan.x_cost
    sepet.append("Soğan")
    print(f"Sepetiniz: {sepet}, Güncel Tutar: {total}TL")
  elif extra_choice == "16":
    print("Mısır Sepetinize Eklendi.\n")
    total += x_misir.x_cost
    sepet.append("Mısır")
    print(f"Sepetiniz: {sepet}, Güncel Tutar: {total}TL")
  
  get_customer_info()
 
  display_goodbye()
# Out:
# Merhaba Hoşgeldiniz. Siparişinizi Almaya Hazırım!
#
# *****PİZZALAR*****
# Türk Pizza, 115TL.
# Geleneksel Türk Mutfağı Lezzetleri ile Harmanlanmış Pizza!
#
# Sade Pizza, 85TL.
# Lezzeti Yoğun Kendisi Sade!
#
# Margarita, 95TL.
# Enfes Mozeralla Peyniri ve Taze Fesleğen ile...
#
# Klasik Pizza, 75TL.
# Klasik Olsun Bizim Olsun Diyenlere...
#
# ******EK MALZEMELER******
# Ek ürün: Ekstra Zeytin. Fiyatı: 15TL
# İnce Doğranmış Siyah Zeytin.
#
# Ek ürün: Kültür Mantarı. Fiyatı: 10TL
# İnce Kesim Kültür Mantarı.
#
# Ek ürün: Keçi Peyniri. Fiyatı: 25TL
# Taze Keçi Peyniri.
#
# Ek ürün: Kırmızı Et. Fiyatı: 35TL
# Kavrulmuş, Jülyen Kırmızı Et.
#
# Ek ürün: Soğan. Fiyatı: 15TL
# İnce Kesim Beyaz Soğan
#
# Ek ürün: Mısır. Fiyatı: 15TL
# Tane Süt Mısır.
#
# Pizzanızı Seçiniz
# (1)Klasik Pizza, (2)Sade Pizza, (3)Margarita, (4)Türk Pizza, Onay İçin (ENTER)
# ---> Seçiminiz:
# 3
# Margarita Sepetinize Eklendi.
#
# Sepetiniz: ['Margarita'], Güncel Tutar: 95TL
# Ekstra Ürün Seçiniz
# ...

# %%
import datetime
